# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadrezaTale/EDA-for-Datasets/blob/main/Global_Marine_EDA_%26_Viz_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Global Marine Data
# ####Historical marine data are comprised of ship, buoy, and platform observations from 1662-present. Data values are delayed by one month. In addition to location, ship identification, ship speed, and ship direction, weather elements observed include: wind direction and speed, visibility, present and past weather, sea level pressure, dry bulb, wet bulb, and dew point temperatures, sea surface temperature, cloud data, wave data, and ice accretion.

# %% [markdown]
# ##import packages and Dataset

# %%
#import packages
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#import dataset
# !gdown --id 1BwK9PrRoK9400LEFU-WFVyP6xu2QIhIt
df = pd.read_csv('Marine_CSV_sample.csv')
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1BwK9PrRoK9400LEFU-WFVyP6xu2QIhIt
# To: /content/Marine_CSV_sample.csv
# 100% 7.02k/7.02k [00:00<00:00, 20.1MB/s]

# %% [markdown]
# ##Data examination

# %%
df.head()
# Out:
#   Identification  Latitude  Longitude  Time of Observation  \
# 0          D5GN6     -35.8        2.9  2015-01-12T00:00:00
# 1          D5GN6     -35.9        6.9  2015-01-12T12:00:00
# 2          D5GN6     -35.9        8.6  2015-01-12T18:00:00
# 3          D5GN6     -35.7       11.9  2015-01-13T06:00:00
# 4          D5GN6     -35.6       13.7  2015-01-13T12:00:00
#
#   Ice Accretion On Ship Thickness of Ice Accretion On Ship  \
# 0
# 1
# 2
# 3
# 4
#
#   Rate of Ice Accretion on Ship Sea Level Pressure  \
# 0                                            29.83
# 1                                            29.93
# 2                                            30.02
# 3                                            30.14
# 4                                            30.12
#
#   Characteristics of Pressure Tendency Pressure Tendency  ...  \
# 0                                    8               0.0  ...
# 1                                    1               0.0  ...
# ...

# %%
df.shape
# Out:
# (55, 33)

# %%
df.describe()
# Out:
#         Latitude  Longitude  Visibility  Wind Direction  Wind Speed
# count  55.000000  55.000000   55.000000       55.000000   55.000000
# mean  -20.558182  51.829091   97.527273      161.127273  108.345455
# std    13.168181  27.141806    0.503857       99.436757   69.483336
# min   -35.900000   2.900000   97.000000       20.000000   10.000000
# 25%   -32.300000  29.000000   97.000000       90.000000   69.500000
# 50%   -23.900000  51.200000   98.000000      140.000000  108.000000
# 75%   -11.200000  75.950000   98.000000      215.000000  139.000000
# max     6.100000  94.600000   98.000000      362.000000  463.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 33 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Identification                        55 non-null     object
#  1   Latitude                              55 non-null     float64
#  2   Longitude                             55 non-null     float64
#  3   Time of Observation                   55 non-null     object
#  4   Ice Accretion On Ship                 55 non-null     object
#  5   Thickness of Ice Accretion On Ship    55 non-null     object
#  6   Rate of Ice Accretion on Ship         55 non-null     object
#  7   Sea Level Pressure                    55 non-null     object
#  8   Characteristics of Pressure Tendency  55 non-null     object
#  9   Pressure Tendency                     55 non-null     object
#  10  Air Temperature                       55 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# Identification                          0
# Latitude                                0
# Longitude                               0
# Time of Observation                     0
# Ice Accretion On Ship                   0
# Thickness of Ice Accretion On Ship      0
# Rate of Ice Accretion on Ship           0
# Sea Level Pressure                      0
# Characteristics of Pressure Tendency    0
# Pressure Tendency                       0
# Air Temperature                         0
# Wet Bulb Temperature                    0
# Dew Point Temperature                   0
# Sea Surface Temperature                 0
# Wave Direction                          0
# Wave Period                             0
# Wave Height                             0
# Swell Direction                         0
# Swell Period                            0
# Swell Height                            0
# Total Cloud Amount                      0
# Low Cloud Amount                        0
# ...

# %%
df.replace(['',' '],pd.NA, inplace=True)

# %%
df.head()
# Out:
#   Identification  Latitude  Longitude  Time of Observation  \
# 0          D5GN6     -35.8        2.9  2015-01-12T00:00:00
# 1          D5GN6     -35.9        6.9  2015-01-12T12:00:00
# 2          D5GN6     -35.9        8.6  2015-01-12T18:00:00
# 3          D5GN6     -35.7       11.9  2015-01-13T06:00:00
# 4          D5GN6     -35.6       13.7  2015-01-13T12:00:00
#
#   Ice Accretion On Ship Thickness of Ice Accretion On Ship  \
# 0                  <NA>                               <NA>
# 1                  <NA>                               <NA>
# 2                  <NA>                               <NA>
# 3                  <NA>                               <NA>
# 4                  <NA>                               <NA>
#
#   Rate of Ice Accretion on Ship Sea Level Pressure  \
# 0                          <NA>              29.83
# 1                          <NA>              29.93
# 2                          <NA>              30.02
# ...

# %%
df.isnull().sum()
# Out:
# Identification                           0
# Latitude                                 0
# Longitude                                0
# Time of Observation                      0
# Ice Accretion On Ship                   55
# Thickness of Ice Accretion On Ship      55
# Rate of Ice Accretion on Ship           55
# Sea Level Pressure                       1
# Characteristics of Pressure Tendency     1
# Pressure Tendency                        2
# Air Temperature                          1
# Wet Bulb Temperature                    55
# Dew Point Temperature                    1
# Sea Surface Temperature                 55
# Wave Direction                          55
# Wave Period                             27
# Wave Height                             27
# Swell Direction                         33
# Swell Period                            35
# Swell Height                            32
# Total Cloud Amount                       2
# Low Cloud Amount                        37
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 33 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Identification                        55 non-null     object
#  1   Latitude                              55 non-null     float64
#  2   Longitude                             55 non-null     float64
#  3   Time of Observation                   55 non-null     object
#  4   Ice Accretion On Ship                 0 non-null      object
#  5   Thickness of Ice Accretion On Ship    0 non-null      object
#  6   Rate of Ice Accretion on Ship         0 non-null      object
#  7   Sea Level Pressure                    54 non-null     object
#  8   Characteristics of Pressure Tendency  54 non-null     object
#  9   Pressure Tendency                     53 non-null     object
#  10  Air Temperature                       54 non-null     object
# ...

# %% [markdown]
# ##null handling

# %%
Nan_ratio = df.isnull().sum() / len(df)
threshold = 0.4
df_cleaned = df.dropna(axis = 1, thresh=len(df) * (1 - threshold))
df_cleaned
# Out:
#    Identification  Latitude  Longitude  Time of Observation  \
# 0           D5GN6     -35.8        2.9  2015-01-12T00:00:00
# 1           D5GN6     -35.9        6.9  2015-01-12T12:00:00
# 2           D5GN6     -35.9        8.6  2015-01-12T18:00:00
# 3           D5GN6     -35.7       11.9  2015-01-13T06:00:00
# 4           D5GN6     -35.6       13.7  2015-01-13T12:00:00
# 5           D5GN6     -35.4       15.5  2015-01-13T18:00:00
# 6           D5GN6     -35.3       17.1  2015-01-14T00:00:00
# 7           D5GN6     -35.2       18.6  2015-01-14T06:00:00
# 8           D5GN6     -35.2       20.3  2015-01-14T12:00:00
# 9           D5GN6     -35.1       21.8  2015-01-14T18:00:00
# 10          D5GN6     -34.5       24.8  2015-01-15T06:00:00
# 11          D5GN6     -34.0       26.3  2015-01-15T12:00:00
# 12          D5GN6     -33.4       27.5  2015-01-15T18:00:00
# 13          D5GN6     -32.7       28.5  2015-01-16T00:00:00
# 14          D5GN6     -31.9       29.5  2015-01-16T06:00:00
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Identification                        55 non-null     object
#  1   Latitude                              55 non-null     float64
#  2   Longitude                             55 non-null     float64
#  3   Time of Observation                   55 non-null     object
#  4   Sea Level Pressure                    54 non-null     object
#  5   Characteristics of Pressure Tendency  54 non-null     object
#  6   Pressure Tendency                     53 non-null     object
#  7   Air Temperature                       54 non-null     object
#  8   Dew Point Temperature                 54 non-null     object
#  9   Total Cloud Amount                    53 non-null     object
#  10  Cloud Height                          55 non-null     object
# ...

# %%
numeric_cols = df_cleaned.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df_cleaned.select_dtypes(include=['object', 'category']).columns

# %%
df_cleaned[numeric_cols] = df_cleaned[numeric_cols].fillna(df_cleaned[numeric_cols].median())
df_cleaned[categorical_cols] = df_cleaned[categorical_cols].fillna(df_cleaned[categorical_cols].mode().iloc[0])

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Identification                        55 non-null     object
#  1   Latitude                              55 non-null     float64
#  2   Longitude                             55 non-null     float64
#  3   Time of Observation                   55 non-null     object
#  4   Sea Level Pressure                    55 non-null     object
#  5   Characteristics of Pressure Tendency  55 non-null     object
#  6   Pressure Tendency                     55 non-null     object
#  7   Air Temperature                       55 non-null     object
#  8   Dew Point Temperature                 55 non-null     object
#  9   Total Cloud Amount                    55 non-null     object
#  10  Cloud Height                          55 non-null     object
# ...

# %% [markdown]
# ##Outlier handling

# %%
def calculate_outliers_percentage(df):
    outlier_counts = {}
    for column in df.select_dtypes(include=['number']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Calculate outliers
        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
        outlier_counts[column] = len(outliers)

    # Print the percentage of outliers for each column
    for column in outlier_counts:
        percentage = (outlier_counts[column] / len(df)) * 100
        print(f"Percentage of outliers in {column}: {percentage:.2f}%")

# Example usage:
calculate_outliers_percentage(df_cleaned)
# Out:
# Percentage of outliers in Latitude: 0.00%
# Percentage of outliers in Longitude: 0.00%
# Percentage of outliers in Visibility: 0.00%
# Percentage of outliers in Wind Direction: 0.00%
# Percentage of outliers in Wind Speed: 1.82%

# %%
def handle_outliers(df):
    for column in numeric_cols:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Capping
        df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)

    return df

# Apply to both training and test datasets
df_new = handle_outliers(df_cleaned)

# %%
calculate_outliers_percentage(df_new)
# Out:
# Percentage of outliers in Latitude: 0.00%
# Percentage of outliers in Longitude: 0.00%
# Percentage of outliers in Visibility: 0.00%
# Percentage of outliers in Wind Direction: 0.00%
# Percentage of outliers in Wind Speed: 0.00%

# %% [markdown]
# ##Data Viz

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Identification                        55 non-null     object
#  1   Latitude                              55 non-null     float64
#  2   Longitude                             55 non-null     float64
#  3   Time of Observation                   55 non-null     object
#  4   Sea Level Pressure                    55 non-null     object
#  5   Characteristics of Pressure Tendency  55 non-null     object
#  6   Pressure Tendency                     55 non-null     object
#  7   Air Temperature                       55 non-null     object
#  8   Dew Point Temperature                 55 non-null     object
#  9   Total Cloud Amount                    55 non-null     object
#  10  Cloud Height                          55 non-null     object
# ...

# %%
pd.concat((df_new.nunique(),df_new.dtypes),axis=1)
# Out:
#                                        0        1
# Identification                         1   object
# Latitude                              53  float64
# Longitude                             55  float64
# Time of Observation                   55   object
# Sea Level Pressure                    33   object
# Characteristics of Pressure Tendency   8   object
# Pressure Tendency                      1   object
# Air Temperature                       37   object
# Dew Point Temperature                 40   object
# Total Cloud Amount                     8   object
# Cloud Height                           7   object
# Middle Cloud Type                      8   object
# High Cloud Type                        6   object
# Visibility                             2    int64
# Present Weather                        9   object
# Past Weather                           4   object
# Wind Direction                        27    int64
# Wind Speed                            28  float64

# %%
wind = df_new['Wind Speed'].value_counts().sort_index()
wind.plot(kind='bar',figsize=(10,5))
plt.title('Wind Speed')
plt.xlabel('Wind Speed')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df_new['Wind Speed'],
    c='b',
    lw=2,
    alpha=0.8)
plt.title('Wind Speed')
plt.xlabel('Wind Speed')
plt.ylabel('frequency')
plt.show()

# %%
fig = px.line(wind, x=wind.index, y=wind.values, markers=True)
fig.update_layout(title="wind speed", xaxis_title="age", yaxis_title="frequency")
fig.update_traces(
    hoverinfo='all',
    hovertemplate='<b>Wind speed: </b>%{x} <br><i>frequency: </i>%{y}'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# bokeh
output_notebook()
fig = figure(title="wind speed distribution", x_axis_label="wind speed", y_axis_label="frequency", width=800, height=400)
fig.line(x=wind.index, y=wind.values, line_width=2)

hover = HoverTool()
hover.tooltips = [("wind speed", "@x"), ("frequency", "@y")]
fig.add_tools(hover)
show(fig)
# Out:
#   <div id="ff5cf5c3-492a-42a4-9a4e-2a72c5e9a560" data-root-id="p1092" style="display: contents;"></div>
